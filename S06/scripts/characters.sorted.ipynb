# %%
import pandas as pd

# %%
df = pd.read_csv('character.powers.csv')

# %%
df[df.violence == 5]
# Out:
#                    id                name        house  prominence  violence  \
# 4        ramsaybolton       Ramsay Bolton       bolton           4         5
# 5         roosebolton        Roose Bolton       bolton           3         5
# 9        balongreyjoy       Balon Greyjoy      greyjoy           3         5
# 11         nightsking    The Night's King  independent           5         5
# 12         melisandre          Melisandre  independent           4         5
# 13         jaqenhghar        Jaqen H'ghar  independent           4         5
# 14          aryastark          Arya Stark  independent           4         5
# 20    cerseilannister    Cersei Lannister    lannister           5         5
# 23              bronn               Bronn    lannister           3         5
# 24             qyburn              Qyburn    lannister           2         5
# 25      gregorclegane      Gregor Clegane    lannister           2         5
# ...

# %%
df[df.diplomacy == 5]
# Out:
#                    id                name        house  prominence  violence  \
# 0        petyrbaelish       Petyr Baelish        arryn           5         4
# 11         nightsking    The Night's King  independent           5         5
# 12         melisandre          Melisandre  independent           4         5
# 15     threeeyedraven    Three Eyed Raven  independent           3         3
# 18           izembaro            Izembaro  independent           2         1
# 20    cerseilannister    Cersei Lannister    lannister           5         5
# 21     jaimelannister     Jaime Lannister    lannister           4         3
# 28               shae                Shae    lannister           2         1
# 32       doranmartell       Doran Martell      martell           3         2
# 37    tyrionlannister    Tyrion Lannister      meereen           5         5
# 38              varys               Varys      meereen           5         5
# ...

# %%
df[df.prominence == 5]
# Out:
#                    id                name        house  prominence  violence  \
# 0        petyrbaelish       Petyr Baelish        arryn           5         4
# 11         nightsking    The Night's King  independent           5         5
# 20    cerseilannister    Cersei Lannister    lannister           5         5
# 37    tyrionlannister    Tyrion Lannister      meereen           5         5
# 38              varys               Varys      meereen           5         5
# 50            jonsnow            Jon Snow  nightswatch           5         5
# 58         sansastark         Sansa Stark        stark           5         2
# 70  daenerystargaryen  Daenerys Targaryen    targaryen           5         5
#
#     diplomacy
# 0           5
# 11          5
# 20          5
# 37          5
# 38          5
# 50          5
# 58          4
# 70          5

# %%
df[df.prominence == 4]
# Out:
#                    id                name        house  prominence  violence  \
# 4        ramsaybolton       Ramsay Bolton       bolton           4         5
# 7        theongreyjoy       Theon Greyjoy      greyjoy           4         2
# 12         melisandre          Melisandre  independent           4         5
# 13         jaqenhghar        Jaqen H'ghar  independent           4         5
# 14          aryastark          Arya Stark  independent           4         5
# 21     jaimelannister     Jaime Lannister    lannister           4         3
# 22    tommenbaratheon    Tommen Baratheon    lannister           4         2
# 30        ellariasand        Ellaria Sand      martell           4         4
# 39           greyworm           Grey Worm      meereen           4         5
# 41        highsparrow    The High Sparrow        minor           4         4
# 42      davosseaworth      Davos Seaworth        minor           4         3
# ...

# %%
df[df.prominence == 3]
# Out:
#                 id              name        house  prominence  violence  \
# 5      roosebolton      Roose Bolton       bolton           3         5
# 8      yaragreyjoy      Yara Greyjoy      greyjoy           3         4
# 9     balongreyjoy     Balon Greyjoy      greyjoy           3         5
# 15  threeeyedraven  Three Eyed Raven  independent           3         3
# 16            waif          The Waif  independent           3         3
# 23           bronn             Bronn    lannister           3         5
# 31       obarasand        Obara Sand      martell           3         4
# 32    doranmartell     Doran Martell      martell           3         2
# 33     nymeriasand      Nymeria Sand      martell           3         2
# 40       missandei         Missandei      meereen           3         1
# 53  eddisontollett   Eddison Tollett  nightswatch           3         4
# 54            olly              Olly  nightswatch           3         3
# ...

# %%
df[df.prominence == 2]
# Out:
#                    id                name        house  prominence  violence  \
# 1           yohnroyce          Yohn Royce        arryn           2         2
# 2          robinarryn         Robin Arryn        arryn           2         1
# 10       eurongreyjoy       Euron Greyjoy      greyjoy           2         3
# 17             thoros              Thoros  independent           2         4
# 18           izembaro            Izembaro  independent           2         1
# 24             qyburn              Qyburn    lannister           2         5
# 25      gregorclegane      Gregor Clegane    lannister           2         5
# 26     kevanlannister     Kevan Lannister    lannister           2         4
# 27            pycelle             Pycelle    lannister           2         2
# 28               shae                Shae    lannister           2         1
# 29  myrcellabaratheon  Myrcella Baratheon    lannister           2         1
# ...

# %%
df[df.prominence == 1]
# Out:
#                 id             name        house  prominence  violence  \
# 3            marei            Marei        arryn           1         2
# 6      waldabolton     Walda Bolton       bolton           1         2
# 19         kinvara          Kinvara  independent           1         4
# 47      lotharfrey      Lothar Frey        minor           1         3
# 48    razdalmoeraz   Razdal mo Eraz        minor           1         2
# 49    walderrivers    Walder Rivers        minor           1         2
# 57          wunwun          Wun Wun  nightswatch           1         5
# 67   smalljonumber   Smalljon Umber        stark           1         2
# 68  haraldkarstark  Harald Karstark        stark           1         2
# 69     edmuretully     Edmure Tully        stark           1         1
# 77           qhono            Qhono    targaryen           1         4
# 85     dickontarly     Dickon Tarly       tyrell           1         2
# ...
